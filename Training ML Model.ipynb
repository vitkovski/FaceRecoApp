# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
data = np.load('./data/data_pca_50_y_mean.pickle.npz')
data.files
# Out:
# ['arr_0', 'arr_1', 'arr_2']

# %%
X = data['arr_0']
y = data['arr_1']
mean = data['arr_2']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4372, 50), (1094, 50), (4372,), (1094,))

# %% [markdown]
# # Training a Machine Learning Model

# %%
from sklearn.svm import SVC

# %%
model = SVC(C=1.0,kernel='rbf',gamma=0.01,probability=True)

# %%
model.fit(x_train,y_train)
print('model trained sucessfully')
# Out:
# model trained sucessfully

# %%
# score
model.score(x_train,y_train)
# Out:
# 0.8593321134492223

# %%
# score
model.score(x_test,y_test)
# Out:
# 0.8144424131627057

# %% [markdown]
# # Model Evaluation
# - Confusion Matrix
# - Classification Report
# - Kappa Score
# - ROC and AUC (probability)

# %%
from sklearn import metrics

# %%
y_pred = model.predict(x_test)
y_prob = model.predict_proba(x_test) # proability

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
cm = np.concatenate((cm,cm.sum(axis=0).reshape(1,-1)),axis=0)
cm = np.concatenate((cm,cm.sum(axis=1).reshape(-1,1)),axis=1)
plt.imshow(cm)
for i in range(3):
    for j in range(3):
        plt.text(j,i,'%d'%cm[i,j])
        
plt.xticks([0,1])
plt.yticks([0,1])
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
plt.show()

# %%
# classification report
cr = metrics.classification_report(y_test,y_pred,target_names=['male','female'],output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score      support
# male           0.792176  0.733032  0.761457   442.000000
# female         0.827737  0.869632  0.848168   652.000000
# accuracy       0.814442  0.814442  0.814442     0.814442
# macro avg      0.809957  0.801332  0.804812  1094.000000
# weighted avg   0.813370  0.814442  0.813135  1094.000000

# %%
# kappa
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.6099979277814267

# %% [markdown]
# # ROC and AUC

# %%
# roc for female
fpr,tpr,thresh = metrics.roc_curve(y_test,y_prob[:,1])
auc_s = metrics.auc(fpr,tpr)
plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,'-.')
plt.plot([0,1],[0,1],'b--')
for i in range(0,len(thresh),20):
    plt.plot(fpr[i],tpr[i],'^')
    plt.text(fpr[i],tpr[i],"%0.2f"%thresh[i])
    
plt.legend(['AUC Score = %0.2f'%auc_s])

plt.xlabel('False Positve Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characterstics')
plt.show()

# %% [markdown]
# # Hyper Parameter Tuning

# %%
model_tune = SVC()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[1,10,20,30,50,100],
             'kernel':['rbf','poly'],
             'gamma':[0.1,0.05,0.01,0.001,0.002,0.005],
             'coef0':[0,1],
             }

# %%
model_grid = GridSearchCV(model_tune,param_grid=param_grid,scoring='accuracy',cv=5,verbose=2)

# %%
model_grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] C=1, coef0=0, gamma=0.1, kernel=rbf .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .............. C=1, coef0=0, gamma=0.1, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=0, gamma=0.1, kernel=rbf .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV] .............. C=1, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=0, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=0, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=1, coef0=0, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=0, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=0, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=1, coef0=0, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=0, gamma=0.1, kernel=poly, total=   1.6s
# [CV] C=1, coef0=0, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.05, kernel=rbf, total=   1.7s
# [CV] C=1, coef0=0, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=0, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=0, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=0, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=0, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.05, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.05, kernel=poly, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.05, kernel=poly, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.05, kernel=poly, total=   1.0s
# [CV] C=1, coef0=0, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.05, kernel=poly, total=   1.3s
# [CV] C=1, coef0=0, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=0, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.01, kernel=poly, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.01, kernel=poly, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.001, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.001, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.001, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=1, coef0=0, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.001, kernel=poly, total=   1.0s
# [CV] C=1, coef0=0, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.001, kernel=poly, total=   1.0s
# [CV] C=1, coef0=0, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.001, kernel=poly, total=   1.0s
# [CV] C=1, coef0=0, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=1, coef0=0, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.002, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.005, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=0, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=0, gamma=0.005, kernel=rbf, total=   1.0s
# [CV] C=1, coef0=0, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=1, coef0=0, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=1, gamma=0.1, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=1, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=1, gamma=0.1, kernel=rbf, total=   1.6s
# [CV] C=1, coef0=1, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=1, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=1, gamma=0.1, kernel=rbf .............................
# [CV] .............. C=1, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=1, coef0=1, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.1, kernel=poly ............................
# [CV] ............. C=1, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=1, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=1, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=1, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=1, gamma=0.05, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=1, coef0=1, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.05, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.01, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.01, kernel=rbf ............................
# [CV] ............. C=1, coef0=1, gamma=0.01, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.01, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.01, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.01, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.01, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.01, kernel=poly ...........................
# [CV] ............ C=1, coef0=1, gamma=0.01, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.001, kernel=rbf, total=   1.3s
# [CV] C=1, coef0=1, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.001, kernel=rbf, total=   1.3s
# [CV] C=1, coef0=1, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.001, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.001, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.001, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.001, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.002, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.002, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.002, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.002, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.002, kernel=poly, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.002, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=1, coef0=1, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.005, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.005, kernel=rbf, total=   1.2s
# [CV] C=1, coef0=1, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.005, kernel=rbf, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.005, kernel=rbf, total=   1.0s
# [CV] C=1, coef0=1, gamma=0.005, kernel=rbf ...........................
# [CV] ............ C=1, coef0=1, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=1, coef0=1, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.005, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.005, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.005, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.005, kernel=poly, total=   0.8s
# [CV] C=1, coef0=1, gamma=0.005, kernel=poly ..........................
# [CV] ........... C=1, coef0=1, gamma=0.005, kernel=poly, total=   0.9s
# [CV] C=10, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=0, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=0, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=0, gamma=0.1, kernel=poly, total=   1.6s
# [CV] C=10, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=0, gamma=0.1, kernel=poly, total=   1.3s
# [CV] C=10, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=0, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=10, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.05, kernel=poly, total=   1.3s
# [CV] C=10, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=10, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=10, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.01, kernel=rbf, total=   1.2s
# [CV] C=10, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.01, kernel=rbf, total=   1.3s
# [CV] C=10, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.01, kernel=rbf, total=   1.2s
# [CV] C=10, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.01, kernel=rbf, total=   1.2s
# [CV] C=10, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=0, gamma=0.01, kernel=rbf, total=   1.3s
# [CV] C=10, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.01, kernel=poly, total=   1.2s
# [CV] C=10, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=0, gamma=0.01, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.001, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.001, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.001, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.001, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.001, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.002, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.002, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.002, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=0, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.005, kernel=poly, total=   1.3s
# [CV] C=10, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=10, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=10, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=10, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=10, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.05, kernel=rbf, total=   1.7s
# [CV] C=10, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.05, kernel=rbf, total=   1.9s
# [CV] C=10, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.05, kernel=poly, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.05, kernel=poly, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.05, kernel=poly, total=   1.2s
# [CV] C=10, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.01, kernel=rbf, total=   1.5s
# [CV] C=10, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.01, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.01, kernel=rbf, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.01, kernel=rbf, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=10, coef0=1, gamma=0.01, kernel=rbf, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.01, kernel=poly, total=   1.7s
# [CV] C=10, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=10, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.01, kernel=poly, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=10, coef0=1, gamma=0.01, kernel=poly, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.001, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.001, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.001, kernel=poly, total=   0.8s
# [CV] C=10, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.001, kernel=poly, total=   0.8s
# [CV] C=10, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.001, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.002, kernel=rbf, total=   1.0s
# [CV] C=10, coef0=1, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.002, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.002, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.002, kernel=poly, total=   0.9s
# [CV] C=10, coef0=1, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.005, kernel=rbf, total=   1.2s
# [CV] C=10, coef0=1, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=10, coef0=1, gamma=0.005, kernel=rbf, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.005, kernel=poly, total=   1.3s
# [CV] C=10, coef0=1, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=10, coef0=1, gamma=0.005, kernel=poly .........................
# [CV] .......... C=10, coef0=1, gamma=0.005, kernel=poly, total=   1.1s
# [CV] C=20, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=0, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=0, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=0, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=0, gamma=0.1, kernel=poly, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=0, gamma=0.1, kernel=poly, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=0, gamma=0.1, kernel=poly, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=0, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=20, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.05, kernel=poly, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.01, kernel=rbf, total=   1.6s
# [CV] C=20, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.01, kernel=rbf, total=   2.1s
# [CV] C=20, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.01, kernel=rbf, total=   2.1s
# [CV] C=20, coef0=0, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=0, gamma=0.01, kernel=rbf, total=   1.9s
# [CV] C=20, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.01, kernel=poly, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.01, kernel=poly, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.01, kernel=poly, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.01, kernel=poly, total=   1.6s
# [CV] C=20, coef0=0, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=0, gamma=0.01, kernel=poly, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.001, kernel=rbf, total=   1.8s
# [CV] C=20, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.001, kernel=rbf, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.001, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.001, kernel=poly, total=   1.8s
# [CV] C=20, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.001, kernel=poly, total=   1.8s
# [CV] C=20, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.001, kernel=poly, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.001, kernel=poly, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.001, kernel=poly, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.002, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.002, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.002, kernel=rbf, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.002, kernel=rbf, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.002, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.002, kernel=rbf, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.002, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.005, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.005, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.005, kernel=rbf, total=   2.0s
# [CV] C=20, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.005, kernel=rbf, total=   1.6s
# [CV] C=20, coef0=0, gamma=0.005, kernel=rbf ..........................
# [CV] ........... C=20, coef0=0, gamma=0.005, kernel=rbf, total=   1.7s
# [CV] C=20, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=20, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.005, kernel=poly, total=   1.3s
# [CV] C=20, coef0=0, gamma=0.005, kernel=poly .........................
# [CV] .......... C=20, coef0=0, gamma=0.005, kernel=poly, total=   1.8s
# [CV] C=20, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=1, gamma=0.1, kernel=rbf, total=   1.8s
# [CV] C=20, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=1, gamma=0.1, kernel=rbf, total=   1.8s
# [CV] C=20, coef0=1, gamma=0.1, kernel=rbf ............................
# [CV] ............. C=20, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=1, gamma=0.1, kernel=poly, total=   1.1s
# [CV] C=20, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=20, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=20, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=20, coef0=1, gamma=0.1, kernel=poly ...........................
# [CV] ............ C=20, coef0=1, gamma=0.1, kernel=poly, total=   1.0s
# [CV] C=20, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.05, kernel=rbf, total=   1.4s
# [CV] C=20, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.05, kernel=rbf, total=   1.9s
# [CV] C=20, coef0=1, gamma=0.05, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.05, kernel=rbf, total=   1.6s
# [CV] C=20, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=20, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=20, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=20, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=20, coef0=1, gamma=0.05, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.05, kernel=poly, total=   0.9s
# [CV] C=20, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.01, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.01, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.01, kernel=rbf, total=   1.8s
# [CV] C=20, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.01, kernel=rbf, total=   2.1s
# [CV] C=20, coef0=1, gamma=0.01, kernel=rbf ...........................
# [CV] ............ C=20, coef0=1, gamma=0.01, kernel=rbf, total=   1.6s
# [CV] C=20, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.01, kernel=poly, total=   1.8s
# [CV] C=20, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.01, kernel=poly, total=   2.1s
# [CV] C=20, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.01, kernel=poly, total=   2.1s
# [CV] C=20, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.01, kernel=poly, total=   2.4s
# [CV] C=20, coef0=1, gamma=0.01, kernel=poly ..........................
# [CV] ........... C=20, coef0=1, gamma=0.01, kernel=poly, total=   2.4s
# [CV] C=20, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=1, gamma=0.001, kernel=rbf, total=   1.7s
# [CV] C=20, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=1, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=1, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=20, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=1, gamma=0.001, kernel=rbf, total=   1.3s
# [CV] C=20, coef0=1, gamma=0.001, kernel=rbf ..........................
# [CV] ........... C=20, coef0=1, gamma=0.001, kernel=rbf, total=   1.3s
# [CV] C=20, coef0=1, gamma=0.001, kernel=poly .........................
# [CV] .......... C=20, coef0=1, gamma=0.001, kernel=poly, total=   1.0s
# ...
# [CV] C=100, coef0=0, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.05, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.05, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.05, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=0, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.05, kernel=poly, total=   1.9s
# [CV] C=100, coef0=0, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.05, kernel=poly, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.05, kernel=poly, total=   1.6s
# [CV] C=100, coef0=0, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=100, coef0=0, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.05, kernel=poly, total=   1.6s
# [CV] C=100, coef0=0, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=0, gamma=0.01, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=0, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.01, kernel=poly, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=100, coef0=0, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=100, coef0=0, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=100, coef0=0, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=0, gamma=0.01, kernel=poly, total=   1.4s
# [CV] C=100, coef0=0, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.001, kernel=rbf, total=   1.6s
# [CV] C=100, coef0=0, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.001, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=0, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.001, kernel=rbf, total=   1.6s
# [CV] C=100, coef0=0, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.001, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.001, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.001, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.001, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.001, kernel=poly, total=   1.3s
# [CV] C=100, coef0=0, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.002, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=0, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.002, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=0, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.002, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=0, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.002, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=0, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.002, kernel=rbf, total=   1.9s
# [CV] C=100, coef0=0, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.002, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.005, kernel=rbf, total=   2.3s
# [CV] C=100, coef0=0, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.005, kernel=rbf, total=   2.1s
# [CV] C=100, coef0=0, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=0, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.005, kernel=poly, total=   1.3s
# [CV] C=100, coef0=0, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=100, coef0=0, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=0, gamma=0.005, kernel=poly, total=   1.2s
# [CV] C=100, coef0=1, gamma=0.1, kernel=rbf ...........................
# [CV] ............ C=100, coef0=1, gamma=0.1, kernel=rbf, total=   1.7s
# [CV] C=100, coef0=1, gamma=0.1, kernel=rbf ...........................
# [CV] ............ C=100, coef0=1, gamma=0.1, kernel=rbf, total=   1.5s
# [CV] C=100, coef0=1, gamma=0.1, kernel=rbf ...........................
# [CV] ............ C=100, coef0=1, gamma=0.1, kernel=rbf, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.1, kernel=rbf ...........................
# [CV] ............ C=100, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.1, kernel=rbf ...........................
# [CV] ............ C=100, coef0=1, gamma=0.1, kernel=rbf, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.1, kernel=poly ..........................
# [CV] ........... C=100, coef0=1, gamma=0.1, kernel=poly, total=   1.2s
# [CV] C=100, coef0=1, gamma=0.1, kernel=poly ..........................
# [CV] ........... C=100, coef0=1, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.1, kernel=poly ..........................
# [CV] ........... C=100, coef0=1, gamma=0.1, kernel=poly, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.1, kernel=poly ..........................
# [CV] ........... C=100, coef0=1, gamma=0.1, kernel=poly, total=   1.5s
# [CV] C=100, coef0=1, gamma=0.1, kernel=poly ..........................
# [CV] ........... C=100, coef0=1, gamma=0.1, kernel=poly, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.05, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.05, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.05, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.05, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.05, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.05, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.05, kernel=poly, total=   1.3s
# [CV] C=100, coef0=1, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.05, kernel=poly, total=   1.3s
# [CV] C=100, coef0=1, gamma=0.05, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.05, kernel=poly, total=   1.4s
# [CV] C=100, coef0=1, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.01, kernel=rbf, total=   2.3s
# [CV] C=100, coef0=1, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.01, kernel=rbf, total=   2.4s
# [CV] C=100, coef0=1, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.01, kernel=rbf, total=   2.4s
# [CV] C=100, coef0=1, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.01, kernel=rbf, total=   2.3s
# [CV] C=100, coef0=1, gamma=0.01, kernel=rbf ..........................
# [CV] ........... C=100, coef0=1, gamma=0.01, kernel=rbf, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.01, kernel=poly, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.01, kernel=poly, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.01, kernel=poly, total=   2.9s
# [CV] C=100, coef0=1, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.01, kernel=poly, total=   3.3s
# [CV] C=100, coef0=1, gamma=0.01, kernel=poly .........................
# [CV] .......... C=100, coef0=1, gamma=0.01, kernel=poly, total=   3.2s
# [CV] C=100, coef0=1, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.001, kernel=rbf, total=   2.0s
# [CV] C=100, coef0=1, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.001, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=1, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.001, kernel=rbf, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.001, kernel=rbf, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.001, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.001, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=1, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.001, kernel=poly, total=   1.7s
# [CV] C=100, coef0=1, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.001, kernel=poly, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.001, kernel=poly, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.001, kernel=poly, total=   1.7s
# [CV] C=100, coef0=1, gamma=0.001, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.001, kernel=poly, total=   1.6s
# [CV] C=100, coef0=1, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.002, kernel=rbf, total=   1.8s
# [CV] C=100, coef0=1, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.002, kernel=rbf, total=   1.9s
# [CV] C=100, coef0=1, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.002, kernel=rbf, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.002, kernel=rbf, total=   1.9s
# [CV] C=100, coef0=1, gamma=0.002, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.002, kernel=rbf, total=   1.9s
# [CV] C=100, coef0=1, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.002, kernel=poly, total=   2.6s
# [CV] C=100, coef0=1, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.002, kernel=poly, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.002, kernel=poly, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.002, kernel=poly, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.002, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.002, kernel=poly, total=   2.1s
# [CV] C=100, coef0=1, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.005, kernel=rbf, total=   2.2s
# [CV] C=100, coef0=1, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.005, kernel=rbf, total=   2.8s
# [CV] C=100, coef0=1, gamma=0.005, kernel=rbf .........................
# [CV] .......... C=100, coef0=1, gamma=0.005, kernel=rbf, total=   3.1s
# [CV] C=100, coef0=1, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.005, kernel=poly, total=   3.8s
# [CV] C=100, coef0=1, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.005, kernel=poly, total=   3.0s
# [CV] C=100, coef0=1, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.005, kernel=poly, total=   3.0s
# [CV] C=100, coef0=1, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.005, kernel=poly, total=   2.8s
# [CV] C=100, coef0=1, gamma=0.005, kernel=poly ........................
# [CV] ......... C=100, coef0=1, gamma=0.005, kernel=poly, total=   2.9s
# [Parallel(n_jobs=1)]: Done 720 out of 720 | elapsed: 17.4min finished
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 10, 20, 30, 50, 100], 'coef0': [0, 1],
#                          'gamma': [0.1, 0.05, 0.01, 0.001, 0.002, 0.005],
#                          'kernel': ['rbf', 'poly']},
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'C': 10, 'coef0': 1, 'gamma': 0.002, 'kernel': 'poly'}

# %%
model_grid.best_score_
# Out:
# 0.7877801398629469

# %%
# WIth best parameter buil ML Model
model_best = SVC(C=30,kernel='rbf',gamma=0.002,probability=True)

# %%
model_best.fit(x_train,y_train)
model_best.score(x_test,y_test)
# Out:
# 0.8107861060329068

# %%
y_pred = model_best.predict(x_test)
y_prob = model_best.predict_proba(x_test) # proability

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
cm = np.concatenate((cm,cm.sum(axis=0).reshape(1,-1)),axis=0)
cm = np.concatenate((cm,cm.sum(axis=1).reshape(-1,1)),axis=1)
plt.imshow(cm)
for i in range(3):
    for j in range(3):
        plt.text(j,i,'%d'%cm[i,j])
        
plt.xticks([0,1])
plt.yticks([0,1])
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
plt.show()

# %%
# classification report
cr = metrics.classification_report(y_test,y_pred,target_names=['male','female'],output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score      support
# male           0.784504  0.733032  0.757895   442.000000
# female         0.826725  0.863497  0.844711   652.000000
# accuracy       0.810786  0.810786  0.810786     0.810786
# macro avg      0.805615  0.798264  0.801303  1094.000000
# weighted avg   0.809667  0.810786  0.809635  1094.000000

# %%
# kappa
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.6028989370096689

# %% [markdown]
# # ROC and AUC

# %%
# roc for female
fpr,tpr,thresh = metrics.roc_curve(y_test,y_prob[:,1])
auc_s = metrics.auc(fpr,tpr)
plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,'-.')
plt.plot([0,1],[0,1],'b--')
for i in range(0,len(thresh),20):
    plt.plot(fpr[i],tpr[i],'^')
    plt.text(fpr[i],tpr[i],"%0.2f"%thresh[i])
    
plt.legend(['AUC Score = %0.2f'%auc_s])

plt.xlabel('False Positve Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characterstics')
plt.show()

# %%
# save our machine learning model
import pickle

# %%
pickle.dump(model_best,open('model_svm.pickle','wb'))

# %%
pickle.dump(mean,open('./model/mean_preprocess.pickle','wb'))
